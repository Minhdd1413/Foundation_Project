# %% [markdown]
# Import Thư viện

# %%
import numpy as np
import json
import glob
import librosa

# %% [markdown]
# #### COUGHVID-3
# - Link: https://www.kaggle.com/datasets/dineshcr7/coughvid-3
# - ![image.png](attachment:image.png)

# %%
dir = 'F:/Audio_data/coughvid_20211012/*'
data_dir = glob.glob(dir)
data_dir
# Out:
# ['F:/Audio_data/coughvid_20211012\\00014dcc-0f06-4c27-8c7b-737b18a2cf4c.json',
#  'F:/Audio_data/coughvid_20211012\\00014dcc-0f06-4c27-8c7b-737b18a2cf4c.webm',
#  'F:/Audio_data/coughvid_20211012\\00039425-7f3a-42aa-ac13-834aaa2b6b92.json',
#  'F:/Audio_data/coughvid_20211012\\00039425-7f3a-42aa-ac13-834aaa2b6b92.webm',
#  'F:/Audio_data/coughvid_20211012\\0007c6f1-5441-40e6-9aaf-a761d8f2da3b.json',
#  'F:/Audio_data/coughvid_20211012\\0007c6f1-5441-40e6-9aaf-a761d8f2da3b.webm',
#  'F:/Audio_data/coughvid_20211012\\00098cdb-4da1-4aa7-825a-4f1b9abc214b.json',
#  'F:/Audio_data/coughvid_20211012\\00098cdb-4da1-4aa7-825a-4f1b9abc214b.wav',
#  'F:/Audio_data/coughvid_20211012\\0009eb28-d8be-4dc1-92bb-907e53bc5c7a.json',
#  'F:/Audio_data/coughvid_20211012\\0009eb28-d8be-4dc1-92bb-907e53bc5c7a.webm',
#  'F:/Audio_data/coughvid_20211012\\0012c608-33d0-4ef7-bde3-75a0b1a0024e.json',
#  'F:/Audio_data/coughvid_20211012\\0012c608-33d0-4ef7-bde3-75a0b1a0024e.webm',
# ...

# %%
with open(data_dir[0], 'r') as f:
    data = json.load(f)
data
# Out:
# {'datetime': '2020-11-25T18:58:50.488301+00:00',
#  'cough_detected': '0.0155',
#  'latitude': '48.9',
#  'longitude': '2.4'}

# %% [markdown]
# Do tập data COUGHVID bao gồm cả webm và wav audio file nên phải convert hết thành dạng wav cho thư viện librosa đọc

# %%
# %pip install --upgrade urllib3
# Out:
# ...
#   Found existing installation: urllib3 2.0.6
#     Uninstalling urllib3-2.0.6:
#       Successfully uninstalled urllib3-2.0.6
# ...
# Note: you may need to restart the kernel to use updated packages.
# moviepy 1.0.3 has requirement decorator<5.0,>=4.0.2, but you'll have decorator 5.1.1 which is incompatible.
# You are using pip version 10.0.1, however version 23.3.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from moviepy.editor import VideoFileClip

# Specify the path to the webm file
webm_file = data_dir[1]

# Open the webm file
video = VideoFileClip(webm_file)
# Specify the path for the output wav file
wav_file = 'C:/Users/Mink/"OneDrive - Phenikaa Univesity"/Uni/DACS/Data_processing/output.wav'

# Convert webm to wav
video.audio.write_audiofile(wav_file)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12848\729742444.py in <module>
# ----> 1 from moviepy.editor import VideoFileClip
#       2
#       3 # Specify the path to the webm file
#       4 webm_file = data_dir[1]
#       5
#
# c:\Users\Mink\AppData\Local\Programs\Python\Python37\lib\site-packages\moviepy\editor.py in <module>
#      36 from .video.io.VideoFileClip import VideoFileClip
#      37 from .video.io.ImageSequenceClip import ImageSequenceClip
# ---> 38 from .video.io.downloader import download_webfile
#      39 from .video.VideoClip import VideoClip, ImageClip, ColorClip, TextClip
#      40 from .video.compositing.CompositeVideoClip import CompositeVideoClip, clips_array
#
# c:\Users\Mink\AppData\Local\Programs\Python\Python37\lib\site-packages\moviepy\video\io\downloader.py in <module>
#       5 import os
#       6
# ...

# %%
audio_data, sr = librosa.load(data_dir[1])
print(audio_data)
print(sr)
# Out:
# C:\Users\Mink\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   """Entry point for launching an IPython kernel.
# c:\Users\Mink\AppData\Local\Programs\Python\Python37\lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# c:\Users\Mink\AppData\Local\Programs\Python\Python37\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     174         try:
# --> 175             y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     176
#
# ...

# %%
for idx, dir in enumerate(data_dir):
    if idx % 2 == 0:
        with open(dir, 'r') as f:
            data = json.load(f)
    else:
        audio_data, sr = librosa.load(dir)
# Out:
# C:\Users\Mink\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   import sys
# c:\Users\Mink\AppData\Local\Programs\Python\Python37\lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# c:\Users\Mink\AppData\Local\Programs\Python\Python37\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     174         try:
# --> 175             y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     176
#
# ...
